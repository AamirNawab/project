# %%
import pandas as pd
import os
import subprocess as sp
# C:\Users\aamir\OneDrive\Desktop\HACE_Project

# %%
# Make new directory
try:
    sp.check_output("dir C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project", shell = True)
except:
    os.mkdir("C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project")

# %%
#Check if that worked 
if sp.check_output("dir C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\", shell = True):
    print('File exists')
else:
    print("File Does Not Exist")
# Out:
# File exists

# %%
# Move a file to newly created directory
try:
    sp.check_output("dir C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\High_income.csv", shell = True)
except:
    os.system("copy C:\\Users\\aamir\\Downloads\\High_income.csv C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\")

# %%
if sp.check_output("dir C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\High_income.csv", shell = True):
    print('File exists')
else:
    print("File Does Not Exist")
# Out:
# File exists

# %%
# function to read CSV and excel files
def read_data(file_url):
    try:
        data = pd.read_csv(file_url)
    except:
        data = pd.read_excel(file_url)
        return(data)

# %%
read_data(r'C:\Users\aamir\OneDrive\Documents\!ASDM\hotel_reviews.xls')
# Out:
#                 ID          Hotel/Restaurant name Location  \
# 0      rn579778340  Thong Dee The Kathu Brasserie    Kathu
# 1      rn576350875  Thong Dee The Kathu Brasserie    Kathu
# 2      rn574921678  Thong Dee The Kathu Brasserie    Kathu
# 3      rn572905503  Thong Dee The Kathu Brasserie    Kathu
# 4      rn572364712  Thong Dee The Kathu Brasserie    Kathu
# ...            ...                            ...      ...
# 53639  rn162368197                        Bite in   Patong
# 53640  rn161843734                        Bite in   Patong
# 53641  rn161734077                        Bite in   Patong
# 53642  rn161218072                        Bite in   Patong
# 53643  rn161212765                        Bite in   Patong
#
#                     Review Date  \
# 0          Reviewed 1 week ago
# 1         Reviewed 3 weeks ago
# 2         Reviewed 4 weeks ago
# 3      Reviewed April 12, 2018
# 4      Reviewed April 10, 2018
# ...                         ...
# ...

# %%
#Test File local system
read_data("C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\High_income.csv")
# Out:
#     Countries   Years  Trade in services (% of GDP)  \
# 0      France  1990.0                     10.982815
# 1      France  1991.0                     11.407801
# 2      France  1992.0                     11.788331
# 3      France  1993.0                     11.780058
# 4      France  1994.0                     10.374065
# ..        ...     ...                           ...
# 96     Cyprus  1996.0                     47.306047
# 97     Cyprus  1997.0                     47.220156
# 98     Cyprus  1998.0                     49.520338
# 99     Cyprus  1999.0                     49.876284
# 100       NaN     NaN                     52.727301
#
#      Communications, computer, etc. (% of service imports, BoP)  \
# 0                                            33.824083
# 1                                            35.061568
# 2                                            25.840913
# 3                                            33.648469
# ...

# %%
# test url 
read_data('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data')
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
import wget
import zipfile
import os.path

# %%
#Function to Unzip Files
path = "C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\zip_files"
import os

def unzip(url):
    zip_file = wget.download(url)
    with zipfile.ZipFile(zip_file, 'r') as zip_obj:
        zip_obj.extractall(path)
    logdir= path # path to directory
    logfiles = sorted([ f for f in os.listdir(logdir) if f.endswith('.csv')])
    data = read_data(path + "\\"+logfiles[-1],)
    return(data)

# %%
#Test function
lend = "https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip"
unzip(lend)
# Out:
# -1 / unknown

# %%
lend = "https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip"
read_data("C:\\Users\\aamir\\OneDrive\\Desktop\\HACE_Project\\zip_files\\LoanStats_2018Q4.csv")
# Out:
# c:\users\aamir\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# ...
